# %%
import os
import string

from textblob import TextBlob

from nltk.corpus import stopwords

# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

# %%
path = os.getcwd()+'\\data'
fileList = os.listdir(path)

fileList[:4]
# Out:
# ['2008_44_pid=29751.txt',
#  '2008_44_pid=62272.txt',
#  '2008_44_pid=73120.txt',
#  '2008_44_pid=76232.txt']

# %%
pathToFile = path + '\\' + fileList[3]
with open(pathToFile, 'r') as f:
    txt = f.readlines()
    
txtList = txt[0].split('.')
txtList[:7]
# Out:
# ['Thank you, Iowa',
#  ' You know, they said this day would never come',
#  ' They said our sights were set too high',
#  ' They said this country was too divided; too disillusioned to ever come together around a common purpose',
#  " But on this January night - at this defining moment in history - you have done what the cynics said we couldn't do",
#  ' You have done what the state of New Hampshire can do in five days',
#  ' You have done what America can do in this New Year, 2008']

# %%
stop = stopwords.words('english')
stop += ['.', ',', '(', ')', "'", '"']

def stringClean(str):
    str = ''.join([i for i in str if i not in string.punctuation])
    words = TextBlob(str).words
    words = ' '.join([w for w in words if w not in stop if len(w)> 1])
    
    return words

updatedTextList = []
for txt in txtList:
    updatedTextList.append(stringClean(txt))
    
updatedTextList
# Out:
# ['Thank Iowa',
#  'You know said day would never come',
#  'They said sights set high',
#  'They said country divided disillusioned ever come together around common purpose',
#  'But January night defining moment history done cynics said couldnt',
#  'You done state New Hampshire five days',
#  'You done America New Year 2008',
#  'In lines stretched around schools churches small towns big cities came together Democrats Republicans Independents stand say one nation one people time change come',
#  'You said time come move beyond bitterness pettiness anger thats consumed Washington end political strategy thats division instead make addition build coalition change stretches Red States Blue States',
#  'Because thats well win November thats well finally meet challenges face nation',
#  'We choosing hope fear',
#  'Were choosing unity division sending powerful message change coming America',
#  'You said time come tell lobbyists think money influence speak louder voices dont government take back',
#  'The time come President honest choices challenges face listen learn even disagree wont tell want hear need know',
#  'And New Hampshire give chance Iowa tonight president America',
#  'Thank',
#  'Ill President finally makes health care affordable available every single American way expanded health care Illinois byby bringing Democrats Republicans together get job done',
#  'Ill President ends tax breaks companies ship jobs overseas put middleclass tax cut pockets working Americans deserve',
#  'Ill President harnesses ingenuity farmers scientists entrepreneurs free nation tyranny oil',
#  'And Ill President ends war Iraq finally brings troops home restores moral standing understands 911 way scare votes challenge unite America world common threats twentyfirst century common threats terrorism nuclear weapons climate change poverty genocide disease',
#  'Tonight one step closer vision America Iowa',
#  'And Id especially like thank organizers precinct captains volunteers staff made possible',
#  'And Im thank yous think makes sense thank love life rock Obama family closer campaign trail give Michelle Obama',
#  'know didnt',
#  'You thisyou believed deeply American ideas face impossible odds people love country change',
#  'know thisI know may standing tonight Ill never forget journey began streets Chicago many done campaign campaigns Iowa organizing working fighting make peoples lives little bit better',
#  'know hard',
#  'It comes little sleep little pay lot sacrifice',
#  'There days disappointment sometimes sometimes nights like nighta night years weve made changes believe families afford see doctor childrenwhen Malia Sasha childreninherit planet thats little cleaner safer world sees America differently America sees nation less divided united youll able look back pride say moment began',
#  'This moment improbable beat Washington always said inevitable',
#  'This moment tore barriers divided us long rallied people parties ages common cause finally gave Americans whod never participated politics reason stand',
#  'This moment finally beat back politics fear doubt cynicism politics tear instead lifting country',
#  'This moment',
#  'Years youll look back youll say moment place America remembered means hope',
#  'For many months weve teased even derided talking hope',
#  'But always knew hope blind optimism',
#  'Its ignoring enormity task ahead roadblocks stand path',
#  'Its sitting sidelines shirking fight',
#  'Hope thing inside us insists despite evidence contrary something better awaits us courage reach work fight',
#  'Hope saw eyes young woman Cedar Rapids works night shift full day college still cant afford health care sister whos ill young woman still believes country give chance live dreams',
#  'Hope heard voice New Hampshire woman told hasnt able breathe since nephew left Iraq still goes bed night praying safe return',
#  'Hope led band colonists rise empire led greatest generations free continent heal nation led young women young men sit lunch counters brave fire hoses march Selma Montgomery freedoms cause',
#  'Hopehopeis led today father Kenya mother Kansas story could happen United States America',
#  'Hope bedrock nation belief destiny written us us men women content settle world courage remake world',
#  'That started Iowa message carry New Hampshire beyond message one change country brick brick block block calloused hand calloused hand together ordinary people extraordinary things collection Red States Blue States United States America moment election ready believe',
#  'Thank Iowa',
#  '']

# %%
# Create a CountVectorizer for parsing/counting words
# make sure we are breaking out by word and not character.
doc_term_vector = CountVectorizer(analyzer='word',
                                  ngram_range=(1,2),
                                  stop_words='english',
                                  token_pattern = '\\b[a-z][a-z]+\\b'
                                 )

doc_term_vector.fit(txtList)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='\\b[a-z][a-z]+\\b',
#         tokenizer=None, vocabulary=None)

# %%
doc_term_vector.get_feature_names()
# Out:
# ['able',
#  'able breathe',
#  'able look',
#  'addition',
#  'addition build',
#  'afford',
#  'afford doctor',
#  'afford health',
#  'affordable',
#  'affordable available',
#  'ages',
#  'ages common',
#  'ahead',
#  'ahead roadblocks',
#  'america',
#  'america did',
#  'america differently',
#  'america moment',
#  'america new',
#  'america remembered',
#  'america sees',
#  'america world',
#  'american',
#  'american ideas',
#  'american way',
#  'americans',
#  'americans deserve',
#  'americans participated',
#  'anger',
#  'anger consumed',
#  'available',
#  'available single',
#  'awaits',
#  'awaits courage',
#  'band',
#  'band colonists',
#  'barriers',
#  'barriers divided',
#  'beat',
#  'beat politics',
#  'beat washington',
#  'bed',
#  'bed night',
#  'bedrock',
#  'bedrock nation',
#  'began',
#  'began streets',
#  'belief',
#  'belief destiny',
#  'believe',
#  'believe families',
#  'believed',
#  'believed deeply',
#  'believes',
#  'believes country',
#  'better',
#  'better awaits',
#  'big',
#  'big cities',
#  'bit',
#  'bit better',
#  'bitterness',
#  'bitterness pettiness',
#  'blind',
#  'blind optimism',
#  'block',
#  'block block',
#  'block calloused',
#  'blue',
#  'blue states',
#  'brave',
#  'brave hoses',
#  'breaks',
#  'breaks companies',
#  'breathe',
#  'breathe nephew',
#  'brick',
#  'brick block',
#  'brick brick',
#  'bringing',
#  'bringing democrats',
#  'brings',
#  'brings troops',
#  'build',
#  'build coalition',
#  'calloused',
#  'calloused hand',
#  'came',
#  'came democrats',
#  'campaign',
#  'campaign campaigns',
#  'campaign trail',
#  'campaigns',
#  'campaigns iowa',
#  'captains',
#  'captains volunteers',
#  'care',
#  'care affordable',
#  'care illinois',
#  'care sister',
#  'carry',
#  'carry new',
#  'cause',
#  'cause finally',
#  'cedar',
#  'cedar rapids',
#  'century',
#  'century common',
#  'challenge',
#  'challenge unite',
#  'challenges',
#  'challenges face',
#  'chance',
#  'chance iowa',
#  'chance live',
#  'change',
#  'change come',
#  'change coming',
#  'change country',
#  'change poverty',
#  'change stretches',
#  'changes',
#  'changes believe',
#  'chicago',
#  'chicago doing',
#  'children',
#  'children inherit',
#  'children malia',
#  'choices',
#  'choices challenges',
#  'choosing',
#  'choosing hope',
#  'choosing unity',
#  'churches',
#  'churches small',
#  'cities',
#  'cities came',
#  'class',
#  'class tax',
#  'cleaner',
#  'cleaner safer',
#  'climate',
#  'climate change',
#  'closer',
#  'closer campaign',
#  'closer vision',
#  'coalition',
#  'coalition change',
#  'collection',
#  'collection red',
#  'college',
#  'college afford',
#  'colonists',
#  'colonists rise',
#  'come',
#  'come bitterness',
#  'come common',
#  'come president',
#  'come tell',
#  'comes',
#  'comes little',
#  'coming',
#  'coming america',
#  'common',
#  'common cause',
#  'common purpose',
#  'common threats',
#  'companies',
#  'companies ship',
#  'consumed',
#  'consumed washington',
#  'content',
#  'content settle',
#  'continent',
#  'continent heal',
#  'contrary',
#  'contrary better',
#  'couldn',
#  'counters',
#  'counters brave',
#  'country',
#  'country brick',
#  'country chance',
#  'country change',
#  'country divided',
#  'courage',
#  'courage reach',
#  'courage remake',
#  'cut',
#  'cut pockets',
#  'cynicism',
#  'cynicism politics',
#  'cynics',
#  'cynics said',
#  'day',
#  'day college',
#  'day come',
#  'days',
#  'days disappointment',
#  'deeply',
#  'deeply american',
#  'defining',
#  'defining moment',
#  'democrats',
#  'democrats republicans',
#  'derided',
#  'derided talking',
#  'deserve',
#  'despite',
#  'despite evidence',
#  'destiny',
#  'destiny written',
#  'did',
#  'did believed',
#  'did did',
#  'did iowa',
#  'did tonight',
#  'didn',
#  'differently',
#  'differently america',
#  'disagree',
#  'disagree won',
#  'disappointment',
#  'disappointment just',
#  'disease',
#  'disillusioned',
#  'disillusioned come',
#  'divided',
#  'divided disillusioned',
#  'divided long',
#  'divided united',
#  'division',
#  'division instead',
#  'division sending',
#  'doctor',
#  'doctor children',
#  'doing',
#  'doing campaign',
#  'don',
#  'don government',
#  'doubt',
#  'doubt cynicism',
#  'dreams',
#  'election',
#  'election ready',
#  'empire',
#  'empire led',
#  'end',
#  'end political',
#  'ends',
#  'ends tax',
#  'ends war',
#  'enormity',
#  'enormity task',
#  'entrepreneurs',
#  'entrepreneurs free',
#  'especially',
#  'especially like',
#  'evidence',
#  'evidence contrary',
#  'expanded',
#  'expanded health',
#  'extraordinary',
#  'extraordinary things',
#  'eyes',
#  'eyes young',
#  'face',
#  'face impossible',
#  'face listen',
#  'face nation',
#  'families',
#  'families afford',
#  'family',
#  'family closer',
#  'farmers',
#  'farmers scientists',
#  'father',
#  'father kenya',
#  'fear',
#  'fear doubt',
#  'fight',
#  'fighting',
#  'fighting make',
#  'finally',
#  'finally beat',
#  'finally brings',
#  'finally gave',
#  'finally makes',
#  'finally meet',
#  'forget',
#  'forget journey',
#  'free',
#  'free continent',
#  'free nation',
#  'freedom',
#  'freedom cause',
#  'gave',
#  'gave americans',
#  'generations',
#  'generations free',
#  'genocide',
#  'genocide disease',
#  'goes',
#  'goes bed',
#  'government',
#  'greatest',
#  'greatest generations',
#  'hampshire',
#  'hampshire chance',
#  'hampshire days',
#  'hampshire message',
#  'hampshire woman',
#  'hand',
#  'hand calloused',
#  'hand ordinary',
#  'happen',
#  'happen united',
#  'hard',
#  'harnesses',
#  'harnesses ingenuity',
#  'hasn',
#  'hasn able',
#  'heal',
#  'heal nation',
#  'health',
#  'health care',
#  'hear',
#  'hear need',
#  'heard',
#  'heard voice',
#  'high',
#  'history',
#  'history cynics',
#  'home',
#  'home restores',
#  'honest',
#  'honest choices',
#  'hope',
#  'hope bedrock',
#  'hope blind',
#  'hope fear',
#  'hope heard',
#  'hope hope',
#  'hope led',
#  'hope saw',
#  'hope thing',
#  'hoses',
#  'hoses march',
#  'ideas',
#  'ideas face',
#  'ignoring',
#  'ignoring enormity',
#  'ill',
#  'ill young',
#  'illinois',
#  'illinois bringing',
#  'impossible',
#  'impossible odds',
#  'improbable',
#  'improbable beat',
#  'independents',
#  'independents stand',
#  'inevitable',
#  'influence',
#  'influence speak',
#  'ingenuity',
#  'ingenuity farmers',
#  'inherit',
#  'inherit planet',
#  'inside',
#  'inside insists',
#  'insists',
#  'insists despite',
#  'instead',
#  'instead lifting',
#  'instead make',
#  'iowa',
#  'iowa did',
#  'iowa message',
#  'iowa organizing',
#  'iraq',
#  'iraq finally',
#  'iraq goes',
#  'january',
#  'january night',
#  'job',
#  'jobs',
#  'jobs overseas',
#  'journey',
#  'journey began',
#  'just',
#  'just little',
#  'just nights',
#  'just tell',
#  'kansas',
#  'kansas story',
#  'kenya',
#  'kenya mother',
#  'knew',
#  'knew hope',
#  'know',
#  'know didn',
#  'know hard',
#  'know know',
#  'know said',
#  'know standing',
#  'learn',
#  'learn disagree',
#  'led',
#  'led band',
#  'led greatest',
#  'led today',
#  'led young',
#  'left',
#  'left iraq',
#  'life',
#  'life rock',
#  'lifting',
#  'lifting country',
#  'like',
#  'like night',
#  'like thank',
#  'lines',
#  'lines stretched',
#  'listen',
#  'listen learn',
#  'little',
#  'little bit',
#  'little cleaner',
#  'little pay',
#  'little sleep',
#  'live',
#  'live dreams',
#  'lives',
#  'lives just',
#  'll',
#  'll able',
#  'll finally',
#  'll forget',
#  'll look',
#  'll president',
#  'll say',
#  'll win',
#  'lobbyists',
#  'lobbyists think',
#  'long',
#  'long rallied',
#  'look',
#  'look ll',
#  'look pride',
#  'lot',
#  'lot sacrifice',
#  'louder',
#  'louder voices',
#  'love',
#  'love country',
#  'love life',
#  'lunch',
#  'lunch counters',
#  'make',
#  'make addition',
#  'make people',
#  'makes',
#  'makes health',
#  'makes sense',
#  'malia',
#  'malia sasha',
#  'march',
#  'march selma',
#  'means',
#  'means hope',
#  'meet',
#  'meet challenges',
#  'men',
#  'men sit',
#  'men women',
#  'message',
#  'message carry',
#  'message change',
#  'michelle',
#  'michelle obama',
#  'middle',
#  'middle class',
#  'moment',
#  'moment began',
#  'moment election',
#  'moment finally',
#  'moment history',
#  'moment improbable',
#  'moment place',
#  'moment tore',
#  'money',
#  'money influence',
#  'montgomery',
#  'montgomery freedom',
#  'months',
#  'months ve',
#  'moral',
#  'moral standing',
#  'mother',
#  'mother kansas',
#  'nation',
#  'nation belief',
#  'nation divided',
#  'nation led',
#  'nation people',
#  'nation tyranny',
#  'need',
#  'need know',
#  'nephew',
#  'nephew left',
#  'new',
#  'new hampshire',
#  'new year',
#  'night',
#  'night defining',
#  'night night',
#  'night praying',
#  'night shift',
#  'night years',
#  'nights',
#  'nights like',
#  'november',
#  'november ll',
#  'nuclear',
#  'nuclear weapons',
#  'obama',
#  'obama family',
#  'odds',
#  'odds people',
#  'oil',
#  'optimism',
#  'ordinary',
#  'ordinary people',
#  'organizers',
#  'organizers precinct',
#  'organizing',
#  'organizing working',
#  'overseas',
#  'overseas middle',
#  'participated',
#  'participated politics',
#  'parties',
#  'parties ages',
#  'path',
#  'pay',
#  'pay lot',
#  'people',
#  'people extraordinary',
#  'people lives',
#  'people love',
#  'people parties',
#  'people time',
#  'pettiness',
#  'pettiness anger',
#  'place',
#  'place america',
#  'planet',
#  'planet little',
#  'pockets',
#  'pockets working',
#  'political',
#  'political strategy',
#  'politics',
#  'politics fear',
#  'politics reason',
#  'politics tear',
#  'possible',
#  'poverty',
#  'poverty genocide',
#  'powerful',
#  'powerful message',
#  'praying',
#  'praying safe',
#  'precinct',
#  'precinct captains',
#  'president',
#  'president america',
#  'president ends',
#  'president finally',
#  'president harnesses',
#  'president honest',
#  'pride',
#  'pride say',
#  'purpose',
#  'rallied',
#  'rallied people',
#  'rapids',
#  'rapids works',
#  'reach',
#  'reach work',
#  'ready',
#  'ready believe',
#  'reason',
#  'reason stand',
#  'red',
#  'red states',
#  'remake',
#  'remake world',
#  'remembered',
#  'remembered means',
#  'republicans',
#  'republicans independents',
#  'republicans job',
#  'restores',
#  'restores moral',
#  'return',
#  'rise',
#  'rise empire',
#  'roadblocks',
#  'roadblocks stand',
#  'rock',
#  'rock obama',
#  'sacrifice',
#  'safe',
#  'safe return',
#  'safer',
#  'safer world',
#  'said',
#  'said couldn',
#  'said country',
#  'said day',
#  'said inevitable',
#  'said sights',
#  'said time',
#  'sasha',
#  'sasha children',
#  'saw',
#  'saw eyes',
#  'say',
#  'say moment',
#  'say nation',
#  'scare',
#  'scare votes',
#  'schools',
#  'schools churches',
#  'scientists',
#  'scientists entrepreneurs',
#  'sees',
#  'sees america',
#  'sees nation',
#  'selma',
#  'selma montgomery',
#  'sending',
#  'sending powerful',
#  'sense',
#  'sense thank',
#  'set',
#  'set high',
#  'settle',
#  'settle world',
#  'shift',
#  'shift day',
#  'ship',
#  'ship jobs',
#  'shirking',
#  'shirking fight',
#  'sidelines',
#  'sidelines shirking',
#  'sights',
#  'sights set',
#  'single',
#  'single american',
#  'sister',
#  'sister ill',
#  'sit',
#  'sit lunch',
#  'sitting',
#  'sitting sidelines',
#  'sleep',
#  'sleep little',
#  'small',
#  'small towns',
#  'speak',
#  'speak louder',
#  'staff',
#  'staff possible',
#  'stand',
#  'stand path',
#  'stand say',
#  'standing',
#  'standing tonight',
#  'standing understands',
#  'started',
#  'started iowa',
#  'state',
#  'state new',
#  'states',
#  'states america',
#  'states blue',
#  'states united',
#  'step',
#  'step closer',
#  'story',
#  'story happen',
#  'strategy',
#  'strategy division',
#  'streets',
#  'streets chicago',
#  'stretched',
#  'stretched schools',
#  'stretches',
#  'stretches red',
#  'talking',
#  'talking hope',
#  'task',
#  'task ahead',
#  'tax',
#  'tax breaks',
#  'tax cut',
#  'tear',
#  'tear instead',
#  'teased',
#  'teased derided',
#  'tell',
#  'tell lobbyists',
#  'tell want',
#  'terrorism',
#  'terrorism nuclear',
#  'thank',
#  'thank iowa',
#  'thank love',
#  'thank organizers',
#  'thank yous',
#  'thing',
#  'thing inside',
#  'things',
#  'things collection',
#  'think',
#  'think makes',
#  'think money',
#  'threats',
#  'threats century',
#  'threats terrorism',
#  'time',
#  'time change',
#  'time come',
#  'today',
#  'today father',
#  'told',
#  'told hasn',
#  'tonight',
#  'tonight ll',
#  'tonight president',
#  'tonight step',
#  'tore',
#  'tore barriers',
#  'towns',
#  'towns big',
#  'trail',
#  'trail michelle',
#  'troops',
#  'troops home',
#  'tyranny',
#  'tyranny oil',
#  'understands',
#  'understands way',
#  'unite',
#  'unite america',
#  'united',
#  'united ll',
#  'united states',
#  'unity',
#  'unity division',
#  've',
#  've changes',
#  've teased',
#  'vision',
#  'vision america',
#  'voice',
#  'voice new',
#  'voices',
#  'voices don',
#  'volunteers',
#  'volunteers staff',
#  'votes',
#  'votes challenge',
#  'want',
#  'want hear',
#  'war',
#  'war iraq',
#  'washington',
#  'washington end',
#  'washington said',
#  'way',
#  'way expanded',
#  'way scare',
#  'weapons',
#  'weapons climate',
#  'win',
#  'win november',
#  'woman',
#  'woman believes',
#  'woman cedar',
#  'woman told',
#  'women',
#  'women content',
#  'women young',
#  'won',
#  'won just',
#  'work',
#  'work fight',
#  'working',
#  'working americans',
#  'working fighting',
#  'works',
#  'works night',
#  'world',
#  'world common',
#  'world courage',
#  'world sees',
#  'written',
#  'written men',
#  'year',
#  'years',
#  'years ll',
#  'years ve',
#  'young',
#  'young men',
#  'young woman',
#  'young women',
#  'yous',
#  'yous think']

# %%
# Create the term-document matrix
# Transpose it so the terms are the rows
term_docs = doc_term_vector.transform(updatedTextList).transpose()
term_docs.shape
# Out:
# (823, 47)

# %%
# Convert sparse matrix of counts to a gensim corpus
# here corpus will be fed into lda in iteration
corpus = matutils.Sparse2Corpus(term_docs)

# %%
id2word = dict((v,k) for k, v in doc_term_vector.vocabulary_.items())

# %%
# Create lda model (equivalent to "fit" in sklearn)
# we can also run lsa on this:
# lsa = models.LsiModel(corpus=corpus, num_topics)
lda = models.LdaModel(corpus=corpus, num_topics=3, id2word=id2word, passes=20)

# %%
lda.print_topics(num_words=20, num_topics=5)
# Out:
# [(0,
#   '0.009*know + 0.008*states + 0.008*thank + 0.007*come + 0.007*iowa + 0.005*moment + 0.005*said + 0.005*time + 0.005*country + 0.005*message + 0.005*time come + 0.005*politics + 0.005*change + 0.004*new + 0.004*hampshire + 0.004*new hampshire + 0.004*finally + 0.004*people + 0.004*stand + 0.004*campaign'),
#  (1,
#   '0.007*ill + 0.007*president + 0.006*change + 0.006*health + 0.006*health care + 0.006*care + 0.006*said + 0.004*hope + 0.004*finally + 0.004*common + 0.004*woman + 0.004*country + 0.004*way + 0.004*common threats + 0.004*american + 0.004*threats + 0.004*republicans + 0.004*democrats republicans + 0.004*democrats + 0.004*young woman'),
#  (2,
#   '0.011*america + 0.010*hope + 0.008*nation + 0.008*led + 0.008*moment + 0.006*night + 0.006*world + 0.004*new + 0.004*say + 0.004*young + 0.004*united + 0.004*tax + 0.004*able + 0.004*years + 0.004*say moment + 0.004*look + 0.004*sees + 0.004*men + 0.004*women + 0.002*days')]

# %%
# here we are looking into top words that pertain to topic 0
lda.get_topic_terms(2,topn=10)
# Out:
# [(435, 0.0076053105301616929),
#  (283, 0.0076047394541385481),
#  (163, 0.0058656881312008418),
#  (563, 0.0058437955283436099),
#  (511, 0.0058409355384847848),
#  (483, 0.0041434358182013496),
#  (440, 0.0041049268952231058),
#  (115, 0.0041024087217231917),
#  (576, 0.0041013536640147792),
#  (687, 0.0040948915104582814)]

# %%
# above we see that word id 376 has the highest
# probability of being in topic 0
# from below the word is iowa
lda.id2word
# Out:
# {0: 'able',
#  1: 'able breathe',
#  2: 'able look',
#  3: 'addition',
#  4: 'addition build',
#  5: 'afford',
#  6: 'afford doctor',
#  7: 'afford health',
#  8: 'affordable',
#  9: 'affordable available',
#  10: 'ages',
#  11: 'ages common',
#  12: 'ahead',
#  13: 'ahead roadblocks',
#  14: 'america',
#  15: 'america did',
#  16: 'america differently',
#  17: 'america moment',
#  18: 'america new',
#  19: 'america remembered',
#  20: 'america sees',
#  21: 'america world',
#  22: 'american',
#  23: 'american ideas',
#  24: 'american way',
#  25: 'americans',
#  26: 'americans deserve',
#  27: 'americans participated',
#  28: 'anger',
#  29: 'anger consumed',
#  30: 'available',
#  31: 'available single',
#  32: 'awaits',
#  33: 'awaits courage',
#  34: 'band',
#  35: 'band colonists',
#  36: 'barriers',
#  37: 'barriers divided',
#  38: 'beat',
#  39: 'beat politics',
#  40: 'beat washington',
#  41: 'bed',
#  42: 'bed night',
#  43: 'bedrock',
#  44: 'bedrock nation',
#  45: 'began',
#  46: 'began streets',
#  47: 'belief',
#  48: 'belief destiny',
#  49: 'believe',
#  50: 'believe families',
#  51: 'believed',
#  52: 'believed deeply',
#  53: 'believes',
#  54: 'believes country',
#  55: 'better',
#  56: 'better awaits',
#  57: 'big',
#  58: 'big cities',
#  59: 'bit',
#  60: 'bit better',
#  61: 'bitterness',
#  62: 'bitterness pettiness',
#  63: 'blind',
#  64: 'blind optimism',
#  65: 'block',
#  66: 'block block',
#  67: 'block calloused',
#  68: 'blue',
#  69: 'blue states',
#  70: 'brave',
#  71: 'brave hoses',
#  72: 'breaks',
#  73: 'breaks companies',
#  74: 'breathe',
#  75: 'breathe nephew',
#  76: 'brick',
#  77: 'brick block',
#  78: 'brick brick',
#  79: 'bringing',
#  80: 'bringing democrats',
#  81: 'brings',
#  82: 'brings troops',
#  83: 'build',
#  84: 'build coalition',
#  85: 'calloused',
#  86: 'calloused hand',
#  87: 'came',
#  88: 'came democrats',
#  89: 'campaign',
#  90: 'campaign campaigns',
#  91: 'campaign trail',
#  92: 'campaigns',
#  93: 'campaigns iowa',
#  94: 'captains',
#  95: 'captains volunteers',
#  96: 'care',
#  97: 'care affordable',
#  98: 'care illinois',
#  99: 'care sister',
#  100: 'carry',
#  101: 'carry new',
#  102: 'cause',
#  103: 'cause finally',
#  104: 'cedar',
#  105: 'cedar rapids',
#  106: 'century',
#  107: 'century common',
#  108: 'challenge',
#  109: 'challenge unite',
#  110: 'challenges',
#  111: 'challenges face',
#  112: 'chance',
#  113: 'chance iowa',
#  114: 'chance live',
#  115: 'change',
#  116: 'change come',
#  117: 'change coming',
#  118: 'change country',
#  119: 'change poverty',
#  120: 'change stretches',
#  121: 'changes',
#  122: 'changes believe',
#  123: 'chicago',
#  124: 'chicago doing',
#  125: 'children',
#  126: 'children inherit',
#  127: 'children malia',
#  128: 'choices',
#  129: 'choices challenges',
#  130: 'choosing',
#  131: 'choosing hope',
#  132: 'choosing unity',
#  133: 'churches',
#  134: 'churches small',
#  135: 'cities',
#  136: 'cities came',
#  137: 'class',
#  138: 'class tax',
#  139: 'cleaner',
#  140: 'cleaner safer',
#  141: 'climate',
#  142: 'climate change',
#  143: 'closer',
#  144: 'closer campaign',
#  145: 'closer vision',
#  146: 'coalition',
#  147: 'coalition change',
#  148: 'collection',
#  149: 'collection red',
#  150: 'college',
#  151: 'college afford',
#  152: 'colonists',
#  153: 'colonists rise',
#  154: 'come',
#  155: 'come bitterness',
#  156: 'come common',
#  157: 'come president',
#  158: 'come tell',
#  159: 'comes',
#  160: 'comes little',
#  161: 'coming',
#  162: 'coming america',
#  163: 'common',
#  164: 'common cause',
#  165: 'common purpose',
#  166: 'common threats',
#  167: 'companies',
#  168: 'companies ship',
#  169: 'consumed',
#  170: 'consumed washington',
#  171: 'content',
#  172: 'content settle',
#  173: 'continent',
#  174: 'continent heal',
#  175: 'contrary',
#  176: 'contrary better',
#  177: 'couldn',
#  178: 'counters',
#  179: 'counters brave',
#  180: 'country',
#  181: 'country brick',
#  182: 'country chance',
#  183: 'country change',
#  184: 'country divided',
#  185: 'courage',
#  186: 'courage reach',
#  187: 'courage remake',
#  188: 'cut',
#  189: 'cut pockets',
#  190: 'cynicism',
#  191: 'cynicism politics',
#  192: 'cynics',
#  193: 'cynics said',
#  194: 'day',
#  195: 'day college',
#  196: 'day come',
#  197: 'days',
#  198: 'days disappointment',
#  199: 'deeply',
#  200: 'deeply american',
#  201: 'defining',
#  202: 'defining moment',
#  203: 'democrats',
#  204: 'democrats republicans',
#  205: 'derided',
#  206: 'derided talking',
#  207: 'deserve',
#  208: 'despite',
#  209: 'despite evidence',
#  210: 'destiny',
#  211: 'destiny written',
#  212: 'did',
#  213: 'did believed',
#  214: 'did did',
#  215: 'did iowa',
#  216: 'did tonight',
#  217: 'didn',
#  218: 'differently',
#  219: 'differently america',
#  220: 'disagree',
#  221: 'disagree won',
#  222: 'disappointment',
#  223: 'disappointment just',
#  224: 'disease',
#  225: 'disillusioned',
#  226: 'disillusioned come',
#  227: 'divided',
#  228: 'divided disillusioned',
#  229: 'divided long',
#  230: 'divided united',
#  231: 'division',
#  232: 'division instead',
#  233: 'division sending',
#  234: 'doctor',
#  235: 'doctor children',
#  236: 'doing',
#  237: 'doing campaign',
#  238: 'don',
#  239: 'don government',
#  240: 'doubt',
#  241: 'doubt cynicism',
#  242: 'dreams',
#  243: 'election',
#  244: 'election ready',
#  245: 'empire',
#  246: 'empire led',
#  247: 'end',
#  248: 'end political',
#  249: 'ends',
#  250: 'ends tax',
#  251: 'ends war',
#  252: 'enormity',
#  253: 'enormity task',
#  254: 'entrepreneurs',
#  255: 'entrepreneurs free',
#  256: 'especially',
#  257: 'especially like',
#  258: 'evidence',
#  259: 'evidence contrary',
#  260: 'expanded',
#  261: 'expanded health',
#  262: 'extraordinary',
#  263: 'extraordinary things',
#  264: 'eyes',
#  265: 'eyes young',
#  266: 'face',
#  267: 'face impossible',
#  268: 'face listen',
#  269: 'face nation',
#  270: 'families',
#  271: 'families afford',
#  272: 'family',
#  273: 'family closer',
#  274: 'farmers',
#  275: 'farmers scientists',
#  276: 'father',
#  277: 'father kenya',
#  278: 'fear',
#  279: 'fear doubt',
#  280: 'fight',
#  281: 'fighting',
#  282: 'fighting make',
#  283: 'finally',
#  284: 'finally beat',
#  285: 'finally brings',
#  286: 'finally gave',
#  287: 'finally makes',
#  288: 'finally meet',
#  289: 'forget',
#  290: 'forget journey',
#  291: 'free',
#  292: 'free continent',
#  293: 'free nation',
#  294: 'freedom',
#  295: 'freedom cause',
#  296: 'gave',
#  297: 'gave americans',
#  298: 'generations',
#  299: 'generations free',
#  300: 'genocide',
#  301: 'genocide disease',
#  302: 'goes',
#  303: 'goes bed',
#  304: 'government',
#  305: 'greatest',
#  306: 'greatest generations',
#  307: 'hampshire',
#  308: 'hampshire chance',
#  309: 'hampshire days',
#  310: 'hampshire message',
#  311: 'hampshire woman',
#  312: 'hand',
#  313: 'hand calloused',
#  314: 'hand ordinary',
#  315: 'happen',
#  316: 'happen united',
#  317: 'hard',
#  318: 'harnesses',
#  319: 'harnesses ingenuity',
#  320: 'hasn',
#  321: 'hasn able',
#  322: 'heal',
#  323: 'heal nation',
#  324: 'health',
#  325: 'health care',
#  326: 'hear',
#  327: 'hear need',
#  328: 'heard',
#  329: 'heard voice',
#  330: 'high',
#  331: 'history',
#  332: 'history cynics',
#  333: 'home',
#  334: 'home restores',
#  335: 'honest',
#  336: 'honest choices',
#  337: 'hope',
#  338: 'hope bedrock',
#  339: 'hope blind',
#  340: 'hope fear',
#  341: 'hope heard',
#  342: 'hope hope',
#  343: 'hope led',
#  344: 'hope saw',
#  345: 'hope thing',
#  346: 'hoses',
#  347: 'hoses march',
#  348: 'ideas',
#  349: 'ideas face',
#  350: 'ignoring',
#  351: 'ignoring enormity',
#  352: 'ill',
#  353: 'ill young',
#  354: 'illinois',
#  355: 'illinois bringing',
#  356: 'impossible',
#  357: 'impossible odds',
#  358: 'improbable',
#  359: 'improbable beat',
#  360: 'independents',
#  361: 'independents stand',
#  362: 'inevitable',
#  363: 'influence',
#  364: 'influence speak',
#  365: 'ingenuity',
#  366: 'ingenuity farmers',
#  367: 'inherit',
#  368: 'inherit planet',
#  369: 'inside',
#  370: 'inside insists',
#  371: 'insists',
#  372: 'insists despite',
#  373: 'instead',
#  374: 'instead lifting',
#  375: 'instead make',
#  376: 'iowa',
#  377: 'iowa did',
#  378: 'iowa message',
#  379: 'iowa organizing',
#  380: 'iraq',
#  381: 'iraq finally',
#  382: 'iraq goes',
#  383: 'january',
#  384: 'january night',
#  385: 'job',
#  386: 'jobs',
#  387: 'jobs overseas',
#  388: 'journey',
#  389: 'journey began',
#  390: 'just',
#  391: 'just little',
#  392: 'just nights',
#  393: 'just tell',
#  394: 'kansas',
#  395: 'kansas story',
#  396: 'kenya',
#  397: 'kenya mother',
#  398: 'knew',
#  399: 'knew hope',
#  400: 'know',
#  401: 'know didn',
#  402: 'know hard',
#  403: 'know know',
#  404: 'know said',
#  405: 'know standing',
#  406: 'learn',
#  407: 'learn disagree',
#  408: 'led',
#  409: 'led band',
#  410: 'led greatest',
#  411: 'led today',
#  412: 'led young',
#  413: 'left',
#  414: 'left iraq',
#  415: 'life',
#  416: 'life rock',
#  417: 'lifting',
#  418: 'lifting country',
#  419: 'like',
#  420: 'like night',
#  421: 'like thank',
#  422: 'lines',
#  423: 'lines stretched',
#  424: 'listen',
#  425: 'listen learn',
#  426: 'little',
#  427: 'little bit',
#  428: 'little cleaner',
#  429: 'little pay',
#  430: 'little sleep',
#  431: 'live',
#  432: 'live dreams',
#  433: 'lives',
#  434: 'lives just',
#  435: 'll',
#  436: 'll able',
#  437: 'll finally',
#  438: 'll forget',
#  439: 'll look',
#  440: 'll president',
#  441: 'll say',
#  442: 'll win',
#  443: 'lobbyists',
#  444: 'lobbyists think',
#  445: 'long',
#  446: 'long rallied',
#  447: 'look',
#  448: 'look ll',
#  449: 'look pride',
#  450: 'lot',
#  451: 'lot sacrifice',
#  452: 'louder',
#  453: 'louder voices',
#  454: 'love',
#  455: 'love country',
#  456: 'love life',
#  457: 'lunch',
#  458: 'lunch counters',
#  459: 'make',
#  460: 'make addition',
#  461: 'make people',
#  462: 'makes',
#  463: 'makes health',
#  464: 'makes sense',
#  465: 'malia',
#  466: 'malia sasha',
#  467: 'march',
#  468: 'march selma',
#  469: 'means',
#  470: 'means hope',
#  471: 'meet',
#  472: 'meet challenges',
#  473: 'men',
#  474: 'men sit',
#  475: 'men women',
#  476: 'message',
#  477: 'message carry',
#  478: 'message change',
#  479: 'michelle',
#  480: 'michelle obama',
#  481: 'middle',
#  482: 'middle class',
#  483: 'moment',
#  484: 'moment began',
#  485: 'moment election',
#  486: 'moment finally',
#  487: 'moment history',
#  488: 'moment improbable',
#  489: 'moment place',
#  490: 'moment tore',
#  491: 'money',
#  492: 'money influence',
#  493: 'montgomery',
#  494: 'montgomery freedom',
#  495: 'months',
#  496: 'months ve',
#  497: 'moral',
#  498: 'moral standing',
#  499: 'mother',
#  500: 'mother kansas',
#  501: 'nation',
#  502: 'nation belief',
#  503: 'nation divided',
#  504: 'nation led',
#  505: 'nation people',
#  506: 'nation tyranny',
#  507: 'need',
#  508: 'need know',
#  509: 'nephew',
#  510: 'nephew left',
#  511: 'new',
#  512: 'new hampshire',
#  513: 'new year',
#  514: 'night',
#  515: 'night defining',
#  516: 'night night',
#  517: 'night praying',
#  518: 'night shift',
#  519: 'night years',
#  520: 'nights',
#  521: 'nights like',
#  522: 'november',
#  523: 'november ll',
#  524: 'nuclear',
#  525: 'nuclear weapons',
#  526: 'obama',
#  527: 'obama family',
#  528: 'odds',
#  529: 'odds people',
#  530: 'oil',
#  531: 'optimism',
#  532: 'ordinary',
#  533: 'ordinary people',
#  534: 'organizers',
#  535: 'organizers precinct',
#  536: 'organizing',
#  537: 'organizing working',
#  538: 'overseas',
#  539: 'overseas middle',
#  540: 'participated',
#  541: 'participated politics',
#  542: 'parties',
#  543: 'parties ages',
#  544: 'path',
#  545: 'pay',
#  546: 'pay lot',
#  547: 'people',
#  548: 'people extraordinary',
#  549: 'people lives',
#  550: 'people love',
#  551: 'people parties',
#  552: 'people time',
#  553: 'pettiness',
#  554: 'pettiness anger',
#  555: 'place',
#  556: 'place america',
#  557: 'planet',
#  558: 'planet little',
#  559: 'pockets',
#  560: 'pockets working',
#  561: 'political',
#  562: 'political strategy',
#  563: 'politics',
#  564: 'politics fear',
#  565: 'politics reason',
#  566: 'politics tear',
#  567: 'possible',
#  568: 'poverty',
#  569: 'poverty genocide',
#  570: 'powerful',
#  571: 'powerful message',
#  572: 'praying',
#  573: 'praying safe',
#  574: 'precinct',
#  575: 'precinct captains',
#  576: 'president',
#  577: 'president america',
#  578: 'president ends',
#  579: 'president finally',
#  580: 'president harnesses',
#  581: 'president honest',
#  582: 'pride',
#  583: 'pride say',
#  584: 'purpose',
#  585: 'rallied',
#  586: 'rallied people',
#  587: 'rapids',
#  588: 'rapids works',
#  589: 'reach',
#  590: 'reach work',
#  591: 'ready',
#  592: 'ready believe',
#  593: 'reason',
#  594: 'reason stand',
#  595: 'red',
#  596: 'red states',
#  597: 'remake',
#  598: 'remake world',
#  599: 'remembered',
#  600: 'remembered means',
#  601: 'republicans',
#  602: 'republicans independents',
#  603: 'republicans job',
#  604: 'restores',
#  605: 'restores moral',
#  606: 'return',
#  607: 'rise',
#  608: 'rise empire',
#  609: 'roadblocks',
#  610: 'roadblocks stand',
#  611: 'rock',
#  612: 'rock obama',
#  613: 'sacrifice',
#  614: 'safe',
#  615: 'safe return',
#  616: 'safer',
#  617: 'safer world',
#  618: 'said',
#  619: 'said couldn',
#  620: 'said country',
#  621: 'said day',
#  622: 'said inevitable',
#  623: 'said sights',
#  624: 'said time',
#  625: 'sasha',
#  626: 'sasha children',
#  627: 'saw',
#  628: 'saw eyes',
#  629: 'say',
#  630: 'say moment',
#  631: 'say nation',
#  632: 'scare',
#  633: 'scare votes',
#  634: 'schools',
#  635: 'schools churches',
#  636: 'scientists',
#  637: 'scientists entrepreneurs',
#  638: 'sees',
#  639: 'sees america',
#  640: 'sees nation',
#  641: 'selma',
#  642: 'selma montgomery',
#  643: 'sending',
#  644: 'sending powerful',
#  645: 'sense',
#  646: 'sense thank',
#  647: 'set',
#  648: 'set high',
#  649: 'settle',
#  650: 'settle world',
#  651: 'shift',
#  652: 'shift day',
#  653: 'ship',
#  654: 'ship jobs',
#  655: 'shirking',
#  656: 'shirking fight',
#  657: 'sidelines',
#  658: 'sidelines shirking',
#  659: 'sights',
#  660: 'sights set',
#  661: 'single',
#  662: 'single american',
#  663: 'sister',
#  664: 'sister ill',
#  665: 'sit',
#  666: 'sit lunch',
#  667: 'sitting',
#  668: 'sitting sidelines',
#  669: 'sleep',
#  670: 'sleep little',
#  671: 'small',
#  672: 'small towns',
#  673: 'speak',
#  674: 'speak louder',
#  675: 'staff',
#  676: 'staff possible',
#  677: 'stand',
#  678: 'stand path',
#  679: 'stand say',
#  680: 'standing',
#  681: 'standing tonight',
#  682: 'standing understands',
#  683: 'started',
#  684: 'started iowa',
#  685: 'state',
#  686: 'state new',
#  687: 'states',
#  688: 'states america',
#  689: 'states blue',
#  690: 'states united',
#  691: 'step',
#  692: 'step closer',
#  693: 'story',
#  694: 'story happen',
#  695: 'strategy',
#  696: 'strategy division',
#  697: 'streets',
#  698: 'streets chicago',
#  699: 'stretched',
#  700: 'stretched schools',
#  701: 'stretches',
#  702: 'stretches red',
#  703: 'talking',
#  704: 'talking hope',
#  705: 'task',
#  706: 'task ahead',
#  707: 'tax',
#  708: 'tax breaks',
#  709: 'tax cut',
#  710: 'tear',
#  711: 'tear instead',
#  712: 'teased',
#  713: 'teased derided',
#  714: 'tell',
#  715: 'tell lobbyists',
#  716: 'tell want',
#  717: 'terrorism',
#  718: 'terrorism nuclear',
#  719: 'thank',
#  720: 'thank iowa',
#  721: 'thank love',
#  722: 'thank organizers',
#  723: 'thank yous',
#  724: 'thing',
#  725: 'thing inside',
#  726: 'things',
#  727: 'things collection',
#  728: 'think',
#  729: 'think makes',
#  730: 'think money',
#  731: 'threats',
#  732: 'threats century',
#  733: 'threats terrorism',
#  734: 'time',
#  735: 'time change',
#  736: 'time come',
#  737: 'today',
#  738: 'today father',
#  739: 'told',
#  740: 'told hasn',
#  741: 'tonight',
#  742: 'tonight ll',
#  743: 'tonight president',
#  744: 'tonight step',
#  745: 'tore',
#  746: 'tore barriers',
#  747: 'towns',
#  748: 'towns big',
#  749: 'trail',
#  750: 'trail michelle',
#  751: 'troops',
#  752: 'troops home',
#  753: 'tyranny',
#  754: 'tyranny oil',
#  755: 'understands',
#  756: 'understands way',
#  757: 'unite',
#  758: 'unite america',
#  759: 'united',
#  760: 'united ll',
#  761: 'united states',
#  762: 'unity',
#  763: 'unity division',
#  764: 've',
#  765: 've changes',
#  766: 've teased',
#  767: 'vision',
#  768: 'vision america',
#  769: 'voice',
#  770: 'voice new',
#  771: 'voices',
#  772: 'voices don',
#  773: 'volunteers',
#  774: 'volunteers staff',
#  775: 'votes',
#  776: 'votes challenge',
#  777: 'want',
#  778: 'want hear',
#  779: 'war',
#  780: 'war iraq',
#  781: 'washington',
#  782: 'washington end',
#  783: 'washington said',
#  784: 'way',
#  785: 'way expanded',
#  786: 'way scare',
#  787: 'weapons',
#  788: 'weapons climate',
#  789: 'win',
#  790: 'win november',
#  791: 'woman',
#  792: 'woman believes',
#  793: 'woman cedar',
#  794: 'woman told',
#  795: 'women',
#  796: 'women content',
#  797: 'women young',
#  798: 'won',
#  799: 'won just',
#  800: 'work',
#  801: 'work fight',
#  802: 'working',
#  803: 'working americans',
#  804: 'working fighting',
#  805: 'works',
#  806: 'works night',
#  807: 'world',
#  808: 'world common',
#  809: 'world courage',
#  810: 'world sees',
#  811: 'written',
#  812: 'written men',
#  813: 'year',
#  814: 'years',
#  815: 'years ll',
#  816: 'years ve',
#  817: 'young',
#  818: 'young men',
#  819: 'young woman',
#  820: 'young women',
#  821: 'yous',
#  822: 'yous think'}

# %% [markdown]
# # how about we combined many texts togather and try this out
